# %% [markdown]
# ## number

# %%
123 + 222 # 整数相加
# Out:
# 345

# %% [markdown]
# python的数值类型包括: 整数，浮点数，复数，固定精度的浮点数。内置的数值类型，足以表示大部分的数据，部分类型需要第三方的库。
# 数值类型提供了常见大的数据操作：

# %%
2 ** 100 # 2的100次方， Python3提供了大数类型的表示。
# Out:
# 1267650600228229401496703205376

# %%
1.5 * 4 # 浮点数乘
# Out:
# 6.0

# %% [markdown]
# python还附带了一些有用的数学模块：

# %%
import math
print(math.pi) # 圆周率
print(math.sqrt(85)) # 85开方
# Out:
# 3.141592653589793
# 9.219544457292887

# %% [markdown]
# random模块还提供了一些随机数生成和随机选择的功能：

# %%
import random
random.random()
# Out:
# 0.9673020104476987

# %%
random.choice([1, 2, 3, 4])
# Out:
# 2

# %% [markdown]
# ## String
# String用来记录文本信息，是一种序列类型，序列类型通常由其他元素按照从左到右有序排列。

# %% [markdown]
# ### 序列操作
# String做为一种序列支持序列的所有操作：

# %%
s = 'Spam'
len(s)
# Out:
# 4

# %%
print(s[0])
print(s[1]) # 按照索引获取指定位置的元素，这时序列类型读取元素的通用方式
# Out:
# S
# p

# %%
# 在python中还支持后序的索引
print(s[-1]) # -1表示序列的最后一个元素。其实等价于 len(s)-1
print(s[-2])
# Out:
# m
# a

# %% [markdown]
# 序列类型还支持切片操作，即从序列中获取一片数据，而不是单个元素。切片操作中，如果左侧起始值缺省默认是0，右侧终止值缺省默认是序列的长度

# %%
print(s[1:3]) # 获取序列从1到3，但不包括3的元素
print(s[:]) # 两边缺省则是整个序列，表示 0 : len(s)
# Out:
# pa
# Spam

# %% [markdown]
# ### 不变性
#
# String类型是不可变的，因此不能修改它的值，只能通过修改值产生新的字符串。

# %%
s[0] = 'b' # 不能修改字符换的值
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-23b97349918e> in <module>()
# ----> 1 s[0] = 'b' # 不能修改字符换的值
#
# TypeError: 'str' object does not support item assignment

# %%
s = "z" + s[1:] # 但是可以用新的字符串赋值给同一个变量，这时候旧的s对象被丢弃，新的s对象保存的是新赋值的字符串
print(s)
# Out:
# zpam

# %% [markdown]
# ### 类型特有方法
# 上面介绍的方法是序列类型通用的操作，此外String还有自己特有的一些方法，主要针对字符串进行的操作。

# %%
s = "Spam"

# %%
s.find("pa") # 查找子字符串，并返回起始位置，如果有多个，只返回第一个找到的
# Out:
# 1

# %%
s.replace("pa", "szq") # 替换指定字符串，但并不改变源字符串，而是返回一个新的字符串
# Out:
# 'Sszqm'

# %% [markdown]
# - 其他常用方法

# %%
line = 'aaa,bbb,ccccc,dd'
line.split(",") # 使用指定的字符对字符串进行分割，得到一个列表
# Out:
# ['aaa', 'bbb', 'ccccc', 'dd']

# %%
s = 'spam'
s.upper() # 转成大写
# Out:
# 'SPAM'

# %%
line = 'aaa,bbb,ccccc,dd\n'
line.rstrip().split(",") # 去掉右侧的空格，并使用逗号分割
# Out:
# ['aaa', 'bbb', 'ccccc', 'dd']

# %% [markdown]
# - 字符串格式化输出

# %%
" %s love %s " %("szq", "lqf")
# Out:
# ' szq love lqf '

# %%
print(" {0} love {1} ".format("szq", "lqf"))
print(" {} love {} ".format("szq", "lqf")) # 新版本的Python
# Out:
# szq love lqf
#  szq love lqf

# %% [markdown]
# python3中字符默认是unicode,python2中则是byte，但是可以互相转换

# %%
s = "spam"
sb = b"spam"
print(s, sb) # 通过解码将byte解码为unciode的字符串，同样方向编码
print(s.encode(), sb.decode())
# Out:
# spam b'spam'
# b'spam' spam

# %%
sb.decode('utf-8')  # 指定解码类型
# Out:
# 'spam'

# %% [markdown]
# ## 列表 List
#
# List同样是个序列，但是可变不固定长度， 支持切片等序列操作， 此外还有列表特有的方法

# %%
L =  [123, 'spam', 1.23]

# %%
L.append('NI') ## 在列表末尾添加元素
L
# Out:
# [123, 'spam', 1.23, 'NI']
